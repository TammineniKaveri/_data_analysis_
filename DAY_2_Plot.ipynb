# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
a=[20,30,40,50,60,10] #carona cases in first five days
b=[1,2,3,4,5,6]
plt.plot(b,a,linestyle=":") #plot(x,y) #:,-,-.,--
plt.show()

# %% [markdown]
# runs scored by 10 new players [100,50,91,78,89,25,34,19,9,10] wickets taken by same 10 new players [1,0,2,0,3,7,8,9,7,5] form clusters for batsman and bowlers

# %%
runs=np.array([100,50,91,78,89,25,34,19,9,10])
wickets=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,wickets,color="blue",marker = "h") #b,g,o,r,c,w,k,y,p,m
plt.show()

# %%
plot the scores of 2 students of 5 different subjects [mat,tel,sci,soc,phy] as x-axis and marks of std1-[100,90,80,70,50],std2-[95,85,75,65,45] as y-axis

# %%
std1=[100,90,80,70,50]
std2=[95,85,75,65,45]
sub=["mat","tel","sci","soc","phy"]
plt.plot(sub,std1,label="student1",color="r")
plt.plot(sub,std2,label="student2",color="k")
plt.title("marks vs subjects")
plt.legend()

# %%
std1=[100,90,80,70,50]
std2=[95,85,75,65,45]
sub=["mat","tel","sci","soc","phy"]
plt.subplot(2,1,1)
plt.plot(sub,std1,label="student1",color="r")
plt.subplot(2,1,2)
plt.plot(sub,std2,label="student2",color="k")
plt.legend()

# %% [markdown]
# create subsplots(bar) showing the profits of two companies year=[2019,2020,2021,2022,2022,2023] and a[230,560,780,127,128],b[200,160,270,127,400]

# %%
a=np.array([230,560,780,127,128])
b=np.array([200,160,270,127,400])
print("revenue of A ",a)
print("revenue of B ",b)
profA=np.diff(a)
print("profit of B",profA)
profB=np.diff(b)
print("profit of B",profB)
X=["19-20","20-21","21-22","22-23"]
plt.subplot(1,2,1)
plt.bar(X,profA,label="profit A",color="k")
plt.legend(loc="best")
plt.subplot(1,2,2)
plt.bar(X,profB,label="profit B",color="g")
plt.legend(loc="best")
# Out:
# revenue of A  [230 560 780 127 128]
# revenue of B  [200 160 270 127 400]
# profit of B [ 330  220 -653    1]
# profit of B [ -40  110 -143  273]

# %%
a=([60,25,5,10])
labe=["c","python","c++","ds"]
plt.pie(a,labels=labe)
plt.show()

# %%
a=np.array([60,25,5,10])
labe=["c","python","c++","ds"]
explo=[0.2,0,0,0]
plt.pie(a,labels=labe,explode=explo,startangle=180,shadow=True)
plt.legend(loc="best")
plt.show()

# %%
std1=[100,90,80,70,50]
std2=[95,85,75,65,45]
std3=[99,88,45,90,66]
std4=[90,80,99,96,95]
sub=["mat","tel","sci","soc","phy"]
plt.subplot(2,2,1)
plt.plot(sub,std1,label="student1",color="r")
plt.legend()
plt.subplot(2,2,2)
plt.plot(sub,std2,label="student2",color="k")
plt.legend()
plt.subplot(2,2,3)
plt.plot(sub,std3,label="student3",color="b")
plt.legend()
plt.subplot(2,2,4)
plt.plot(sub,std4,label="student1",color="o")
plt.legend()
